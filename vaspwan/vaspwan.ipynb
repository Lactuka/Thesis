# %%
import matplotlib.pyplot as plt
from matplotlib import rcParamsDefault
import numpy as np


data = np.loadtxt('wannier90_band.dat')

k = np.unique(data[:, 0])
bands = np.reshape(data[:, 1], (-1, len(k)))

fermi_level = -1.3754056185

high_symmetry_points = [0, 0.9828050012, 1.8339476087, 2.3253501094, 3.3081551106]  
high_symmetry_labels = [ 'K', r'$\Gamma$','M', 'K', r'$\Gamma$']

plt.figure(figsize=(14, 8))

for band in range(len(bands)):
    plt.plot(k, bands[band, :]-fermi_level, linewidth=1, alpha=0.7, color='red')
plt.xlim(min(k), max(k))

plt.plot(k, bands[19, :]-fermi_level, linewidth=1, alpha=0.7, color='blue')

plt.axhline(0, color='black', linestyle='--', lw=0.5)
for i in range(len(high_symmetry_points)):
    plt.axvline(high_symmetry_points[i], color='black', linestyle='--', lw=0.5)

plt.xticks(high_symmetry_points, high_symmetry_labels, fontsize=16)
plt.ylabel("Energy (eV)")
#plt.ylim(-5,5)
plt.show()

# %%
import z2pack
import tbmodels
import matplotlib.pyplot as plt

model = tbmodels.Model.from_wannier_files(hr_file='wannier90_hr.dat',wsvec_file='wannier90_wsvec.dat',occ=18)
system = z2pack.tb.System(model)
result = z2pack.surface.run(
    system=system,
    surface=lambda t1, t2: [t1/2,t2,0.5],num_lines=31,iterator=range(30, 101, 5)
)
   # Prints the Chern number

z2pack.plot.wcc(result)
print(z2pack.invariant.z2(result))
plt.show()      # Prints the Z2 invariant
# Out:
# +----------------------------------------------------------------------+
# | ===================                                                  |
# | SURFACE CALCULATION                                                  |
# | ===================                                                  |
# | starting at 2025-11-19 11:03:34,347                                  |
# | running Z2Pack version 2.2.1                                         |
# |                                                                      |
# | gap_tol:            0.3                                              |
# | init_result:        None                                             |
# | iterator:           range(30, 101, 5)                                |
# | load:               False                                            |
# | load_quiet:         True                                             |
# | min_neighbour_dist: 0.01                                             |
# | move_tol:           0.3                                              |
# | num_lines:          31                                               |
# | pos_tol:            0.01                                             |
# | save_file:          None                                             |
# | serializer:         auto                                             |
# | surface:            <function <lambda> at 0x0000015991BF36A0>        |
# | system:             <z2pack.tb.System object at 0x00000159926BBBB0>  |
# +----------------------------------------------------------------------+
#
# INFO: Adding lines required by 'num_lines'.
# INFO: Adding line at t = 0.0
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.03333333333333333
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.06666666666666667
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.1
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.13333333333333333
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.16666666666666666
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.2
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.23333333333333334
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.26666666666666666
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.3
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.3333333333333333
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.36666666666666664
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.4
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.43333333333333335
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.4666666666666667
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.5
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.5333333333333333
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.5666666666666667
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.6
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.6333333333333333
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.6666666666666666
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.7
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.7333333333333333
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.7666666666666666
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.8
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.8333333333333334
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.8666666666666667
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.9
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.9333333333333333
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.9666666666666667
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 1.0
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Convergence criteria fulfilled for 28 of 30 neighbouring lines.
# INFO: Adding line at t = 0.016666666666666666
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Adding line at t = 0.05
# INFO:       Calculating line for N = 30
# INFO:       Calculating line for N = 35
# INFO: Convergence criteria fulfilled for 32 of 32 neighbouring lines.
#
# +----------------------------------------------------------------------+
# |                  Calculation finished in 0h 0m 22s                   |
# +----------------------------------------------------------------------+
# +----------------------------------------------------------------------+
# |                         ==================                           |
# |                         CONVERGENCE REPORT                           |
# |                         ==================                           |
# |                                                                      |
# |                         Line Convergence                             |
# |                         ================                             |
# |                                                                      |
# |                             PosCheck                                 |
# |                             --------                                 |
# |                             PASSED: 33 of 33                         |
# |                                                                      |
# |                         Surface Convergence                          |
# |                         ===================                          |
# |                                                                      |
# |                             GapCheck                                 |
# |                             --------                                 |
# |                             PASSED: 32 of 32                         |
# |                                                                      |
# |                             MoveCheck                                |
# |                             ---------                                |
# |                             PASSED: 32 of 32                         |
# +----------------------------------------------------------------------+
# 1
