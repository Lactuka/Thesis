# %%
import os
from phonopy import Phonopy
from phonopy.interface.vasp import read_vasp ,write_vasp

os.system('phonopy -d --dim=" 4 5 1" --tolerance=1e-6')
# Out:
# 0

# %%
import os 
from phonopy import Phonopy

os.system('phonopy -f 001-vasprun.xml 002-vasprun.xml 003-vasprun.xml 004-vasprun.xml 005-vasprun.xml 006-vasprun.xml 007-vasprun.xml 008-vasprun.xml ')

# %%
import os 
from phonopy import Phonopy

os.system('phonopy -p -s band.conf')
